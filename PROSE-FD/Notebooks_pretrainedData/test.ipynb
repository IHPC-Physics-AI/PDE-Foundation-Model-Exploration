# %% [markdown]
# # PROSE-FD Inference for Pretrained Datasets
#
# Notes for arguments used:
#
# Set model=prose_2to1 to use the model that encodes the PDE equations.
#
# Set log_eval_plots=1 to get plots.
#
# exp_id is the folder name in which your plots will be saved under. Unless changed, location is prose_fd/checkpoint/fluids_test/EXP_ID

# %% [markdown]
# # PDEBench Shallow Water Inference
# No need for any preprocessing.

# %%
# !python prose_fd/main.py \
    eval_only=1 \
    use_wandb=0 \
    eval_from_exp=prose_fd.pth \
    log_eval_plots=1 \
    exp_id=shallow_water_eval \
    batch_size_eval=32 \
    model=prose_2to1 \
    data.types=["shallow_water"]
# Out:
# /usr/local/lib/python3.11/dist-packages/torchdata/datapipes/__init__.py:18: UserWarning:
# ################################################################################
# WARNING!
# The 'datapipes', 'dataloader2' modules are deprecated and will be removed in a
# future torchdata release! Please see https://github.com/pytorch/data/issues/1196
# to learn more and leave feedback.
# ################################################################################
#
#   deprecation_warning()
# INFO - 02/09/26 22:39:33 - 0:00:00 - ============ Initialized logger ============
# INFO - 02/09/26 22:39:33 - 0:00:00 - The experiment will be stored in checkpoint/fluids_test/shallow_water_eval
#
# INFO - 02/09/26 22:39:33 - 0:00:00 - Running command: python prose_fd/main.py 'eval_only=1' 'use_wandb=0' 'eval_from_exp=prose_fd.pth' 'log_eval_plots=-1' 'exp_id=shallow_water_eval' 'batch_size_eval=32' 'model=prose_2to1' 'data.types=[shallow_water]'
#
# ...

# %% [markdown]
# # PDEBench INS Inference
# No need for any preprocessing.

# %%
# !python prose_fd/main.py \
    eval_only=1 \
    use_wandb=0 \
    eval_from_exp=/content/prose_fd.pth \
    log_eval_plots=1 \
    exp_id=incom_ns_eval \
    batch_size_eval=32 \
    model=prose_2to1 \
    data.types=["incom_ns"]
# Out:
# /usr/local/lib/python3.11/dist-packages/torchdata/datapipes/__init__.py:18: UserWarning:
# ################################################################################
# WARNING!
# The 'datapipes', 'dataloader2' modules are deprecated and will be removed in a
# future torchdata release! Please see https://github.com/pytorch/data/issues/1196
# to learn more and leave feedback.
# ################################################################################
#
#   deprecation_warning()
# INFO - 03/23/26 07:57:49 - 0:00:00 - ============ Initialized logger ============
# INFO - 03/23/26 07:57:49 - 0:00:00 - The experiment will be stored in checkpoint/fluids_test/incom_ns_eval
#
# INFO - 03/23/26 07:57:49 - 0:00:00 - Running command: python prose_fd/main.py 'eval_only=1' 'use_wandb=0' 'eval_from_exp=/content/prose_fd.pth' 'log_eval_plots=1' 'exp_id=incom_ns_eval' 'batch_size_eval=32' 'model=prose_2to1' 'data.types=[incom_ns]'
#
# ...

# %% [markdown]
# # PDEArena INS-unconditioned Inference
# No need for any preprocessing.

# %%
# !python /content/prose/prose_fd/main.py \
    eval_only=1 \
    use_wandb=0 \
    eval_from_exp=prose_fd.pth \
    log_eval_plots=5 \
    print_outputs=1 \
    exp_id=incom_ns_arena_u_eval\
    batch_size_eval=10 \
    eval_size=10 \
    model=prose_2to1 \
    data.types=["incom_ns_arena_u"]
# Out:
# /usr/local/lib/python3.11/dist-packages/torchdata/datapipes/__init__.py:18: UserWarning:
# ################################################################################
# WARNING!
# The 'datapipes', 'dataloader2' modules are deprecated and will be removed in a
# future torchdata release! Please see https://github.com/pytorch/data/issues/1196
# to learn more and leave feedback.
# ################################################################################
#
#   deprecation_warning()
# INFO - 03/05/26 22:04:07 - 0:00:00 - ============ Initialized logger ============
# INFO - 03/05/26 22:04:07 - 0:00:00 - The experiment will be stored in checkpoint/fluids_test/incom_ns_arena_u_eval
#
# ...

# %% [markdown]
# # PDEArena INS-conditioned Inference
# No need for any preprocessing.

# %%
# !python /content/prose/prose_fd/main.py \
    eval_only=1 \
    use_wandb=0 \
    eval_from_exp=prose_fd.pth \
    log_eval_plots=5 \
    print_outputs=1 \
    exp_id=incom_ns_arena_c_eval\
    batch_size_eval=10 \
    eval_size=10 \
    model=prose_2to1 \
    data.types=["incom_ns_arena"]
# Out:
# /usr/local/lib/python3.11/dist-packages/torchdata/datapipes/__init__.py:18: UserWarning:
# ################################################################################
# WARNING!
# The 'datapipes', 'dataloader2' modules are deprecated and will be removed in a
# future torchdata release! Please see https://github.com/pytorch/data/issues/1196
# to learn more and leave feedback.
# ################################################################################
#
#   deprecation_warning()
# INFO - 03/09/26 23:01:33 - 0:00:00 - ============ Initialized logger ============
# INFO - 03/09/26 23:01:33 - 0:00:00 - The experiment will be stored in checkpoint/fluids_test/incom_ns_arena_c_eval
#
# ...

# %% [markdown]
# # CFDBench Inference
#
# Cavity, tube and dam flow datasets are used.
#
# Preprocessing is required. It can be done in a notebook cell, like so:
#
# ```python
# from prose.prose_fd.data_utils.convert_cfdbench import preprocess_cfdbench_data  # <-- Adjust the import path according to your file structure
#
# preprocess_cfdbench_data()
# ```
#
# Remember to adjust the data paths in convert_cfdbench.py accordingly.

# %%
# !python /content/prose/prose_fd/main.py \
    eval_only=1 \
    use_wandb=0 \
    eval_from_exp=prose_fd.pth \
    log_eval_plots=5 \
    print_outputs=1 \
    exp_id=cfd_eval\
    batch_size_eval=10 \
    eval_size=10 \
    model=prose_2to1 \
    data.types=["cfdbench"]
# Out:
# /usr/local/lib/python3.11/dist-packages/torchdata/datapipes/__init__.py:18: UserWarning:
# ################################################################################
# WARNING!
# The 'datapipes', 'dataloader2' modules are deprecated and will be removed in a
# future torchdata release! Please see https://github.com/pytorch/data/issues/1196
# to learn more and leave feedback.
# ################################################################################
#
#   deprecation_warning()
# INFO - 03/05/26 23:21:57 - 0:00:00 - ============ Initialized logger ============
# INFO - 03/05/26 23:21:57 - 0:00:00 - The experiment will be stored in checkpoint/fluids_test/cfd_eval
#
# INFO - 03/05/26 23:21:57 - 0:00:00 - Running command: python /content/prose/prose_fd/main.py 'eval_only=1' 'use_wandb=0' 'eval_from_exp=prose_fd.pth' 'log_eval_plots=5' 'print_outputs=1' 'exp_id=cfd_eval' 'batch_size_eval=10' 'eval_size=10' 'model=prose_2to1' 'data.types=[cfdbench]'
#
# ...
